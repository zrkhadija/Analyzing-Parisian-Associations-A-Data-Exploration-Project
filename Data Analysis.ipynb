# %% [markdown]
#  <div style='font-size:100%;'>
#     <a id='import'></a>
#     <h1 style='color: black; font-weight: bold; font-family: Cascadia code;'>
#         <center> Importing necessary libraries 📚 </center>
#     </h1>
#
# </div>

# %%
# import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from numpy import isnan
from pandas import read_csv
from datetime import date
import warnings
warnings.filterwarnings('ignore')

# %%
pip install pandas matplotlib seaborn plotly
# Out:
# ...
#   Using cached plotly-5.18.0-py3-none-any.whl (15.6 MB)
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# ...
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)

# %% [markdown]
# <div style='font-size:100%;'>
#     <a id='import'></a>
#     <h1 style='color: black; font-weight: bold; font-family: Cascadia code;'>
#         <center>importing Dataset  ⬇️  </center>
#     </h1>
#
# </div>

# %%
import pandas as pd
import requests

# Replace 'your_api_endpoint' with the actual API endpoint you want to use
api_endpoint = 'https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/liste_des_associations_parisiennes/records?limit=20'

# Make a GET request to the API
response = requests.get(api_endpoint)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data from the response
    data = response.json()

    # Extract relevant data from the JSON structure
    results = data.get('results', [])

    if results:
        # Convert the JSON data to a DataFrame
        df = pd.DataFrame(results)

        # Now you can work with the DataFrame (e.g., print it)
        print(df)
    else:
        print("No results found in the JSON data.")
else:
    # Print an error message if the request was not successful
    print(f"Error: {response.status_code}")
# Out:
#                                     pr_nom_statutaire  cp_adresse_code_postal  \
# 0                                      TEAM POINT ZEN                   75020
# 1                                    TOURIST-SERVICES                   75015
# 2                              TENNIS CLUB DU 5E TC 5                   75005
# 3                          SPORTS ET LOISIRS PARIS XV                   75011
# 4                                          TENNISPORT                   75017
# 5                                     TÒTES D'AMPOULE                   75020
# 6                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 7                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 8         UGOP, UNE GOUTTE D'ORGANISATION PRODUCTIONS                   75018
# 9                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 10                                   FREQUENCE SCHOOL                   75018
# ...

# %%
print(data)
# Out:
# {'total_count': 70993, 'results': [{'pr_nom_statutaire': 'TEAM POINT ZEN', 'cp_adresse_code_postal': 75020, 'cp_adresse_ville': 'PARIS', 'sa_secteur_d_activit_1': 'Sport', 'sa_secteur_d_activit_2': 'Sant\x82', 'sa_secteur_d_activit_3': 'Vie et animation locale', 'sa_libell_domaine_d_activit': 'Vie Locale et Citoyenne', 'sa_libell_secteur_d_activit': 'Vie et animation locale', 'pv_public_vis': 'Professionnels', 'sg_secteur_gographique': 'International', 'cl_id_partenaire': 2653}, {'pr_nom_statutaire': 'TOURIST-SERVICES', 'cp_adresse_code_postal': 75015, 'cp_adresse_ville': 'PARIS', 'sa_secteur_d_activit_1': 'Loisirs', 'sa_secteur_d_activit_2': 'Tourisme', 'sa_secteur_d_activit_3': 'Aides aux associations', 'sa_libell_domaine_d_activit': 'Sports Loisirs', 'sa_libell_secteur_d_activit': 'Loisirs', 'pv_public_vis': 'Tous', 'sg_secteur_gographique': 'Ile de France', 'cl_id_partenaire': 8484}, {'pr_nom_statutaire': 'TENNIS CLUB DU 5E TC 5', 'cp_adresse_code_postal': 75005, 'cp_adresse_vill
# ...

# %% [markdown]
# <div style='font-size:100%;'>
#     <a id='import'></a>
#     <h1 style='color: black; font-weight: bold; font-family: Cascadia code;'>
#         <center>DataSet Information  ⬇️   </center>
#     </h1>
#
# </div>

# %%
df.describe()
# Out:
#        cp_adresse_code_postal  cl_id_partenaire
# count               20.000000         20.000000
# mean             75012.400000      12033.500000
# std                  5.632612      16649.587349
# min              75005.000000         16.000000
# 25%              75005.000000       2016.000000
# 50%              75013.000000       6049.500000
# 75%              75018.000000      10839.000000
# max              75020.000000      50436.000000

# %%
feature_types = df.dtypes
print(feature_types)
# Out:
# pr_nom_statutaire              object
# cp_adresse_code_postal          int64
# cp_adresse_ville               object
# sa_secteur_d_activit_1         object
# sa_secteur_d_activit_2         object
# sa_secteur_d_activit_3         object
# sa_libell_domaine_d_activit    object
# sa_libell_secteur_d_activit    object
# pv_public_vis                  object
# sg_secteur_gographique         object
# cl_id_partenaire                int64
# dtype: object
# 2023-12-22 16:22:07,385 - INFO     - Executing shutdown...
# C:\Users\Khadija\anaconda\lib\site-packages\dtale\app.py:441: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.

# %%
df
# Out:
#                                     pr_nom_statutaire  cp_adresse_code_postal  \
# 0                                      TEAM POINT ZEN                   75020
# 1                                    TOURIST-SERVICES                   75015
# 2                              TENNIS CLUB DU 5E TC 5                   75005
# 3                          SPORTS ET LOISIRS PARIS XV                   75011
# 4                                          TENNISPORT                   75017
# 5                                     TÒTES D'AMPOULE                   75020
# 6                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 7                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 8         UGOP, UNE GOUTTE D'ORGANISATION PRODUCTIONS                   75018
# 9                 SOYER SPORT ECOLE DE JUDO DES MINES                   75005
# 10                                   FREQUENCE SCHOOL                   75018
# ...

# %%
df.head()
# Out:
#             pr_nom_statutaire  cp_adresse_code_postal cp_adresse_ville  \
# 0              TEAM POINT ZEN                   75020            PARIS
# 1            TOURIST-SERVICES                   75015            PARIS
# 2      TENNIS CLUB DU 5E TC 5                   75005            PARIS
# 3  SPORTS ET LOISIRS PARIS XV                   75011            PARIS
# 4                  TENNISPORT                   75017            PARIS
#
#   sa_secteur_d_activit_1 sa_secteur_d_activit_2   sa_secteur_d_activit_3  \
# 0                  Sport                  Sant  Vie et animation locale
# 1                Loisirs               Tourisme   Aides aux associations
# 2                  Sport                Loisirs    Education & formation
# 3                  Sport                   None                     None
# 4                  Sport                Loisirs    Education & formation
#
#   sa_libell_domaine_d_activit sa_libell_secteur_d_activit   pv_public_vis  \
# ...

# %%
print('list of features:', df.columns.values)
# Out:
# list of features: ['pr_nom_statutaire' 'cp_adresse_code_postal' 'cp_adresse_ville'
#  'sa_secteur_d_activit_1' 'sa_secteur_d_activit_2'
#  'sa_secteur_d_activit_3' 'sa_libell_domaine_d_activit'
#  'sa_libell_secteur_d_activit' 'pv_public_vis' 'sg_secteur_gographique'
#  'cl_id_partenaire']

# %%
print('Simple statistics for float features')
print(df.describe())
# Out:
# Simple statistics for float features
#        cp_adresse_code_postal  cl_id_partenaire
# count               20.000000         20.000000
# mean             75012.400000      12033.500000
# std                  5.632612      16649.587349
# min              75005.000000         16.000000
# 25%              75005.000000       2016.000000
# 50%              75013.000000       6049.500000
# 75%              75018.000000      10839.000000
# max              75020.000000      50436.000000

# %%
# Count NaN values for each column
nan_counts = df.isna().sum()

# Display counts
print(nan_counts)
# Out:
# pr_nom_statutaire              0
# cp_adresse_code_postal         0
# cp_adresse_ville               0
# sa_secteur_d_activit_1         0
# sa_secteur_d_activit_2         2
# sa_secteur_d_activit_3         2
# sa_libell_domaine_d_activit    0
# sa_libell_secteur_d_activit    0
# pv_public_vis                  0
# sg_secteur_gographique         0
# cl_id_partenaire               0
# dtype: int64

# %% [markdown]
# <div style='font-size:100%;'>
#     <a id='import'></a>
#     <h1 style='color: black; font-weight: bold; font-family: Cascadia code;'>
#         <center>Data Visulazation  ⬇️   </center>
#     </h1>
#
# </div>

# %% [markdown]
# ### Bar Chart for Sector of Activity:
# Visualize the distribution of organizations based on their primary sector of activity.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='sa_secteur_d_activit_1', data=df)
plt.title('Distribution of Organizations by Sector of Activity')
plt.xlabel('Sector of Activity')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Countplot for Public Visibility:
# Display the count of organizations based on their public visibility.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='pv_public_vis', data=df)
plt.title('Public Visibility of Organizations')
plt.xlabel('Public Visibility')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Geographical Distribution using Pie Chart:
# Show the distribution of organizations across different geographical sectors.

# %%
plt.figure(figsize=(8, 8))
df['sg_secteur_gographique'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Geographical Distribution of Organizations')
plt.ylabel('')
plt.show()

# %%
# Create a DataFrame with the counts for each combination of sector and geographic place
df_counts = df.groupby(['sg_secteur_gographique', 'sa_secteur_d_activit_1']).size().unstack(fill_value=0)

# Ensure the sectors are ordered for plotting
ordered_sectors = df['sa_secteur_d_activit_1'].value_counts().index
df_counts = df_counts.reindex(columns=ordered_sectors)

# Calculate the percentage of sectors for every place
sector_percentage_by_place = df_counts.div(df_counts.sum(axis=1), axis=0) * 100

# Plotting the stacked bar chart
plt.figure(figsize=(16, 8))
sector_percentage_by_place.plot(kind='bar', stacked=True, colormap='viridis', figsize=(14, 8))
plt.title('Primary Sector of Activity by Geographic Place')
plt.xlabel('Geographic Place')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Primary Sector of Activity', bbox_to_anchor=(1, 1))

# Adding text labels for sector percentages
for i, (place, percentages) in enumerate(sector_percentage_by_place.iterrows()):
    for sector, percentage in percentages.items():
        plt.text(i, percentages.head(ordered_sectors.tolist().index(sector)).sum() + percentage / 2, f'{percentage:.1f}%', ha='center', va='center')

plt.show()

# %% [markdown]
# ###  Word Cloud for Domain of Activity

# %% [raw]
# Create a word cloud to visualize the most common words in the domain of activity.

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)

# %%
from wordcloud import WordCloud

text = ' '.join(df['sa_libell_domaine_d_activit'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Domain of Activity')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['pr_nom_statutaire']))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'sa_libell_secteur_d_activit' and 'pv_public_vis' are the column names in your dataset
sector_public_vis_counts = df.groupby('sa_libell_secteur_d_activit')['pv_public_vis'].value_counts(normalize=True).unstack()

# Plotting the bar plot
ax = sector_public_vis_counts.plot(kind='bar', stacked=True, figsize=(12, 8))

# Adding labels and title
plt.title('Percentage of Public Visibility for Each Sector of Activity')
plt.xlabel('Sector of Activity')
plt.ylabel('Percentage')
plt.legend(title='Public Visibility', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# ### Partners Study

# %%
cl_id_partenaire_counts = df['cl_id_partenaire'].value_counts()

# Display the unique values and their occurrences
print("Unique values and occurrences of 'cl_id_partenaire':")
print(cl_id_partenaire_counts)
# Out:
# Unique values and occurrences of 'cl_id_partenaire':
# 10839    5
# 2016     2
# 49179    2
# 2653     1
# 8484     1
# 3878     1
# 16       1
# 1067     1
# 2996     1
# 4327     1
# 7772     1
# 1595     1
# 861      1
# 50436    1
# Name: cl_id_partenaire, dtype: int64

# %%
df['cl_id_partenaire'].unique()
# Out:
# array([ 2653,  8484,  3878,    16,  1067,  2996, 10839,  4327,  7772,
#         2016,  1595,   861, 50436, 49179], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8))
sns.countplot(x='cl_id_partenaire', hue='sa_secteur_d_activit_1', data=df)
plt.title('Distribution of Partner IDs by Primary Sector of Activity')
plt.xlabel('Partner ID')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Primary Sector of Activity', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ### Advanced Analysis

# %%
pip install plotnine
# Out:
# ...
#   Using cached numpy-1.26.2-cp39-cp39-win_amd64.whl (15.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\Khadija\\anaconda\\Lib\\site-packages\\~~mpy\\.libs\\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll'
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Adjust column names as needed

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.countplot(x='sg_secteur_gographique', hue='pv_public_vis', data=df)
plt.title('Count of pv_public_vis by Geographic Place')
plt.xlabel('Geographic Place')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Khadija\anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 130 (\x82) missing from current font.

# %%
pip install --upgrade plotnine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)

# %%
pip install networkx
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)

# %%
from itertools import combinations
from collections import Counter
import networkx as nx
import matplotlib.pyplot as plt

# Selecting the activity sector columns
activity_sectors = df[['sa_secteur_d_activit_1', 'sa_secteur_d_activit_2', 'sa_secteur_d_activit_3']].dropna()

# Create a list of all unique pairs of activity sectors
all_pairs = []
for _, row in activity_sectors.iterrows():
    sectors = row.dropna().tolist()
    all_pairs.extend(combinations(sectors, 2))

# Count the occurrences of each pair
pair_counts = Counter(all_pairs)

# Calculate the total number of organizations
total_organizations = len(activity_sectors)

# Calculate the probability of each pair
pair_probabilities = {pair: count / total_organizations for pair, count in pair_counts.items()}

# Extract pairs and probabilities for visualization
pairs = list(pair_probabilities.keys())
probabilities = list(pair_probabilities.values())

# Create a graph for visualization
G = nx.Graph()

# Add nodes and edges to the graph
for pair, probability in pair_probabilities.items():
    G.add_edge(pair[0], pair[1], weight=probability)

# Draw the graph with larger figure size and font size
plt.figure(figsize=(14, 10))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=1200, node_color='skyblue', font_size=12)
nx.draw_networkx_edge_labels(G, pos, edge_labels={(edge[0], edge[1]): f'{prob:.2%}' for edge, prob in pair_probabilities.items()}, font_size=10)

plt.title('Probability of Co-occurrence of Activity Sectors')
plt.show()

# %% [markdown]
# # Dtale Library

# %%
pip install dtale
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khadija\appdata\roaming\python\python39\site-packages)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Khadija\anaconda\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Khadija\anaconda\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\Khadija\anaconda\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Khadija\anaconda\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
#   File "C:\Users\Khadija\anaconda\lib\http\client.py", line 506, in readinto
# ...

# %%
import dtale

# %%
dtale.show(df)
# Out:
#  * Tip: There are .env or .flaskenv files present. Do "pip install python-dotenv" to use them.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://KHADIJA:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# C:\Users\Khadija\anaconda\lib\site-packages\dtale\column_analysis.py:512: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# C:\Users\Khadija\anaconda\lib\site-packages\dtale\column_analysis.py:403: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# C:\Users\Khadija\anaconda\lib\site-packages\dtale\column_analysis.py:403: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# ...
